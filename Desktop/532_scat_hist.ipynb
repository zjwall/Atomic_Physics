# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
# %matplotlib inline

data = np.loadtxt('Z:/Group_Share/Barium/Data/2021.dir/12.dir/2021_12_01.dir/00107 - green_shelving_hist.csv', delimiter = ',')
data2 = np.loadtxt('Z:/Group_Share/Barium/Data/2021.dir/11.dir/2021_11_15.dir/00183 - green_shelving_hist.csv', delimiter = ',')

# %%
# print(data)
counts = [i[1] for i in data]
counts2 = [i[1] for i in data2]
plt.hist(counts,  bins= int(max(counts)),edgecolor='k')
plt.hist(counts2,  bins= int(max(counts2)),color='r', edgecolor='k')

plt.yscale('log')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
# %matplotlib inline

data = np.loadtxt('Z:/Group_Share/Barium/Data/2021.dir/12.dir/2021_12_08.dir/00336 - green_shelving_hist.csv', delimiter = ',')
data2 = np.loadtxt('Z:/Group_Share/Barium/Data/2021.dir/12.dir/2021_12_08.dir/00338 - green_shelving_hist.csv', delimiter = ',')

# %%
# print(data)
counts = [i[1] for i in data]
counts2 = [i[1] for i in data2]
plt.hist(counts,  bins= int(max(counts)),edgecolor='k')
plt.hist(counts2,  bins= int(max(counts2)),color='r', edgecolor='k')

plt.yscale('log')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
# %matplotlib inline

data = np.loadtxt('Z:/Group_Share/Barium/Data/2021.dir/12.dir/2021_12_13.dir/00202 - green_shelving_hist.csv', delimiter = ',')
data2 = np.loadtxt('Z:/Group_Share/Barium/Data/2021.dir/12.dir/2021_12_13.dir/00200 - green_shelving_hist.csv', delimiter = ',')
data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2021.dir/12.dir/2021_12_14.dir/00445 - green_shelving_hist.csv', delimiter = ',')

# %%
# print(data)
counts = [i[1] for i in data]
counts2 = [i[1] for i in data2]
counts3 = [i[1] for i in data3]

# plt.hist(counts,  bins= int(max(counts)),edgecolor='k')
plt.hist(counts2,  bins= int(max(counts2)),color='r', edgecolor='k')
plt.hist(counts3,  bins= int(max(counts3)),color='b', edgecolor='k')

plt.yscale('log')
plt.show()

# %%
er = 0
for i in counts2:
    if i<10:
        er +=1
er2=0
for i in counts3:
    if i<12:
        er2+=1
        
print(er,er2)
# Out:
# 3 16

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
# %matplotlib inline

data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2021.dir/12.dir/2021_12_17.dir/00524 - green_shelving_hist.csv', delimiter = ',')
data3 = data3[:20000]
counts = [i[2] for i in data3]
print(len(counts))

dcc = [i[1] for i in data3]
dccind = [i for i in range(len(dcc)) if dcc[i] < 20]
counts = [e for i, e in enumerate(counts) if i not in dccind]
print(len(counts))
# Out:
# 20000
# 19173

# %%
dark = [i for i in counts if i < 10]
print(len(dark))
# Out:
# 2

# %%
# print(data)
counts = [i[1] for i in data]


# plt.hist(counts,  bins= int(max(counts)),edgecolor='k')
plt.hist(counts,  bins= int(max(counts2)),color='r', edgecolor='k')
plt.hist(counts3,  bins= int(max(counts3)),color='b', edgecolor='k')

plt.yscale('log')
plt.show()

# %%
x = [i for i in range(len(counts)) if counts[i] < 10]
y = [e for i, e in enumerate(dcc) if i in x]

print(np.mean(dcc))
print(y)
print(x)
# Out:
# 32.2735
# [26.0, 34.0, 28.0, 37.0]
# [3237, 8426, 16059, 16818]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
# %matplotlib inline

data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2021.dir/12.dir/2021_12_14.dir/0055 - green_shelving_hist.csv', delimiter = ',')

print(len(counts))
counts = [i[2] for i in data3]
dcc = [i[1] for i in data3]
dccind = [i for i in range(len(dcc)) if dcc[i] < 20]
counts = [e for i, e in enumerate(counts) if i not in dcind]
print(len(counts))

dark = [i for i in counts if i < 12]
print(len(dark))

er3=0
for i in counts3:
    if i<12:
        er3+=1

print('mean dcs', mean)
print('total below threshold', er3)
print('exp num', len(counts3))
# print('dc counts for below threhold', dcs3)

er5 = 0
er6 = 0
er7 =0
for i in range(len(counts3)):
    if counts3[i]<12:
#         print(d3[i],d3[i-1],d3[i+1])
        if d3[i] > 15 and  d3[i-1]   > 15 and  d3[i+1] > 15:
            er5 += 1
        if d3[i] > 15:
            er6 += 1

cc = 0
for i in range(5,len(counts3)-5):
    if d3[i] > 15 and  d3[i-1]  > 15 and  d3[i+1] > 15 and d3[i-2]  > 15 and  d3[i+2] > 15 \
            and  d3[i-3] > 15 and d3[i+3] > 15 \
            and  d3[i-4] > 15 and d3[i+4] > 15 \
            and  d3[i-5] > 15 and d3[i+5] > 15:
            cc+=1

for i in range(len(counts3)):
    if counts3[i]<12:
        if d3[i] > 15 and  d3[i-1]  > 15 and  d3[i+1] > 15 and d3[i-2]  > 15 and  d3[i+2] > 15 \
            and  d3[i-3] > 15 and d3[i+3] > 15 \
            and  d3[i-4] > 15 and d3[i+4] > 15 \
            and  d3[i-5] > 15 and d3[i+5] > 15:
            er7+=1            
            
print(er5)
print(er6)
print(er7)
print(cc)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21364/2623109639.py in <module>
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#       6
# ----> 7 data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2021.dir/12.dir/2021_12_14.dir/0055 - green_shelving_hist.csv', delimiter = ',')
#       8
#       9 print(len(counts))
#
# c:\users\zwall\appdata\local\programs\python\python39\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1065             fname = os_fspath(fname)
#    1066         if _is_string_like(fname):
# -> 1067             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1068             fencoding = getattr(fh, 'encoding', 'latin1')
#    1069             fh = iter(fh)
#
# ...

# %%
power = (-60, -40, -32, -23, -22, -15)
tbt = (38, 18, 15, 81, 62, 50)
er1 = (1, 5, 10, 19, 14, 30)
er2 = (0, 2, 5, 10, 9, 25)

# %%
import math
##Plotting Results###
fig = plt.figure()
fig.suptitle('F=0 Prep Error', fontsize=20)
ax = fig.gca()


plt.plot(power, tbt, color = 'darkred',label="total eror without dc threshold")
plt.plot(power, er1, color = 'royalblue',label="error with dc>threshold")
plt.plot(power, er2, color = 'g' ,label="error with dc>threshold + dc +/- 1 > threshold")


plt.xlabel('455 AOM power')
plt.ylabel('Dark Experiments out of 20000')


plt.legend(loc=(1.04,.51))
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
# %matplotlib inline

data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2021.dir/12.dir/2021_12_14.dir/00519 - green_shelving_hist.csv', delimiter = ',')


countsr = [i[2] for i in data3]
print(len(countsr))
dcc = [i[1] for i in data3]
dccind = [i for i in range(5,len(dcc)-5) if dcc[i] < 30 or dcc[i-1] < 30 or dcc[i+1] < 30 ]
counts = [e for i, e in enumerate(countsr) if i not in dccind]
print(len(counts))

dark = [i for i in counts[:19000] if i < 12]
print(len(dark))
print(len(countsr)-len(counts))
# Out:
# 20400
# 19808
# 25
# 592

# %%
power = (-60, -40, -32, -23, -22, -15)
er1 = (0, 3, 10, 19, 14, 35)
dcc_below = (800, 651, 550, 1004, 544, 600)


import math
##Plotting Results###
fig = plt.figure()
fig.suptitle('F=0 Prep Error', fontsize=20)
ax = fig.gca()



plt.plot(power, er1, color = 'royalblue' ,label="error")


plt.xlabel('455 AOM power (dbm)')
plt.ylabel('Dark Experiments out of 20000')


plt.legend(loc=(1.04,.51))
plt.grid()
plt.show()

fig = plt.figure()
fig.suptitle('F=0 Prep Error', fontsize=20)
ax = fig.gca()



plt.plot(power, dcc_below, color = 'darkred',label="total doppler cooling below threshold")

plt.xlabel('455 AOM power (dbm)')
plt.ylabel('Dark at Doppler Cooling Experiments out of 20000')


plt.legend(loc=(1.04,.51))
plt.grid()
plt.show()
