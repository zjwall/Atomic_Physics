# %%
import sympy
from sympy import S
from sympy.physics.wigner import wigner_3j
from sympy.physics.wigner import wigner_6j
import numpy as np
import scipy.constants as sc

I = 2*10/(np.pi*(100e-6)**2)
E = np.sqrt(2*I/(sc.c*sc.epsilon_0))
# w = 2*np.pi*(607.419890e12-1.815e9)
w = 2*np.pi*(563e12)
a = 1/(4*np.pi*sc.epsilon_0*sc.hbar*sc.c)

gam1ps = 2*np.pi*15.2e6
gam2ps = 2*np.pi*18.9e6
gam1pd1 = 2*np.pi*4.9e6
gam2pd1 = 2*np.pi*.733e6
gam2pd2 = 2*np.pi*5.98e6


###i = |F=0, mf=0, L=0> ###
si = S(1)/2
fi = 0
mfi = 0
ji = S(1)/2
li = 0
wi = 2*np.pi*(9.925e9)
q=1

# %%
##--------------------- f = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sf = S(1)/2
ff = 1
mff = -1
jf = S(1)/2
lf = 0

wf = 2*np.pi*(0)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)


##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1ps
gli = gam1ps


##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1ps
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1ps
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2ps
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t41 = mu11*mu12/(wl-w)
t42 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2ps
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t51 = mu11*mu12/(wl-w)
t52 = mu21*mu22/(wl+w-wf)
##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2ps
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t61 = mu11*mu12/(wl-w)
t62 = mu21*mu22/(wl+w-wf)

g1 = (t11+t41+t22+t52)**2
g2 = (t21+t51+t12+t42)**2
g3 = (t31+t61)**2
g6 = (t32+t62)**2
fsum10 = con*(g1+g2+g3+g6)

# %%
##--------------------- f = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sf = S(1)/2
ff = 1
mff = 0
jf = S(1)/2
lf = 0

wf = 2*np.pi*(0)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)


##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1ps
gli = gam1ps


##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1ps
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1ps
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2ps
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t41 = mu11*mu12/(wl-w)
t42 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2ps
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t51 = mu11*mu12/(wl-w)
t52 = mu21*mu22/(wl+w-wf)
##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2ps
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t61 = mu11*mu12/(wl-w)
t62 = mu21*mu22/(wl+w-wf)

g1 = (t11+t41+t32+t62)**2
g2 = (t21+t51+t22+t52)**2
g3 = (t31+t61+t12+t42)**2
g5 = (t22+t52)**2

fsum11 = con*(g1+g2+g3+g5)
print(t31,t61,t12,t42)
print(t21,t51,t22,t52)
# Out:
# -4.86405835109074e-73 2.22125708377187e-73 1.84633941924740e-74 -1.73019496725402e-74
# 0 0 0 0

# %%
##--------------------- f = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sf = S(1)/2
ff = 1
mff = 1
jf = S(1)/2
lf = 0

wf = 2*np.pi*(0)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)


##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1ps
gli = gam1ps


##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1ps
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1ps
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2ps
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t41 = mu11*mu12/(wl-w)
t42 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2ps
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t51 = mu11*mu12/(wl-w)
t52 = mu21*mu22/(wl+w-wf)
##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2ps
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t61 = mu11*mu12/(wl-w)
t62 = mu21*mu22/(wl+w-wf)

g1 = (t11+t41)**2
g2 = (t21+t51+t32+t62)**2
g3 = (t31+t61+t22+t52)**2
g4 = (t12+t42)**2

fsum12 = con*(g1+g2+g3+g4)

print(t31,t61,t22,t52)
# Out:
# 4.86405835109074e-73 -2.22125708377187e-73 1.84633941924740e-74 -1.73019496725402e-74

# %%
print(float(fsum10))
print(fsum11)
print(fsum12)
print('s scatter', fsum10+fsum11+fsum12)
# Out:
# 0.0
# 0.139360085972775
# 0.141831571102234
# s scatter 0.281191657075009

# %%
##--------------------- f = |F=1, J=3/2, L=2, mf=1> -----------------------------##
sf = S(1)/2
ff = 1
mff = -1
jf = S(3)/2
lf = 2

wf = 2*np.pi*(146.11656100000005e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t41 = mu11*mu12/(wl-w)
t42 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t51 = mu11*mu12/(wl-w)
t52 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t61 = mu11*mu12/(wl-w)
t62 = mu21*mu22/(wl+w-wf)


g1 = (t11+t41+t22+t52)**2
g2 = (t21+t51+t12+t42)**2
g3 = (t31+t61)**2
g6 = (t32+t62)**2
fsum210 = con*(g1+g2+g3+g6)

# %%
# --------------------- f = |F=1, J=3/2, L=2, mf=1> -----------------------------##
sf = S(1)/2
ff = 1
mff = 0
jf = S(3)/2
lf = 2

wf = 2*np.pi*(146.11656100000005e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t41 = mu11*mu12/(wl-w)
t42 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t51 = mu11*mu12/(wl-w)
t52 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t61 = mu11*mu12/(wl-w)
t62 = mu21*mu22/(wl+w-wf)


g1 = (t11+t41+t32+t62)**2
g2 = (t21+t51+t22+t52)**2
g3 = (t31+t61+t12+t42)**2
ftest1211 = con*(t31+t61)**2
ftest2211 = con*(t31**2+t61**2)
ftest3211 = con*(t31**2+t61**2+t12**2+t42**2)
fsum211 = con*(g1+g2+g3)

# %%
##--------------------- f = |F=1, J=3/2, L=2, mf=1> -----------------------------##
sf = S(1)/2
ff = 1
mff = 1
jf = S(3)/2
lf = 2

wf = 2*np.pi*(146.11656100000005e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t41 = mu11*mu12/(wl-w)
t42 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t51 = mu11*mu12/(wl-w)
t52 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t61 = mu11*mu12/(wl-w)
t62 = mu21*mu22/(wl+w-wf)


g1 = (t11+t41)**2
g2 = (t21+t51+t32+t62)**2
g3 = (t31+t61+t22+t52)**2
g4 = (t12+t42)**2
ftest1212 = con*(t31+t61)**2
ftest2212 = con*(t31**2+t61**2)
ftest3212 = con*(t31**2+t61**2+t22**2+t52**2)
fsum212 = con*(g1+g2+g3+g4)

# %%
print(float(fsum210))
print(float(fsum211))
print(float(fsum212))
print('d_3/2 F=1 scatter', float(fsum210+fsum211+fsum212))
# print('d_3/2 test 1--no counterrotating F=1 scatter', float(ftest1211+ftest2212))
# print('d_3/2 F=1 test 2 -- no interference no counterrotatting scatter', float(ftest2211+ftest2212))
# print('d_3/2 F=1 test 3 -- no interference scatter', float(ftest3211+ftest3212))
# Out:
# 0.08760251638040945
# 0.0
# 0.08760251638040945
# d_3/2 F=1 scatter 0.1752050327608189

# %%
##--------------------- f = |F=1, J=3/2, L=2, mf=1> -----------------------------##
sf = S(1)/2
ff = 2
mff = -2
jf = S(3)/2
lf = 2

wf = 2*np.pi*(146.11656100000005e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t41 = mu11*mu12/(wl-w)
t42 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t51 = mu11*mu12/(wl-w)
t52 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t61 = mu11*mu12/(wl-w)
t62 = mu21*mu22/(wl+w-wf)


g1 = (t11+t41+t12+t42)**2
g2 = (t21+t51)**2
g3 = (t31+t61)**2
g5 = (t22+t52)**2
g6 = (t32+t62)**2
fsum220 = con*(g1+g2+g3+g4+g5+g6)

# %%
##--------------------- f = |F=1, J=3/2, L=2, mf=1> -----------------------------##
sf = S(1)/2
ff = 2
mff = -1
jf = S(3)/2
lf = 2

wf = 2*np.pi*(146.11656100000005e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t41 = mu11*mu12/(wl-w)
t42 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t51 = mu11*mu12/(wl-w)
t52 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t61 = mu11*mu12/(wl-w)
t62 = mu21*mu22/(wl+w-wf)


g1 = (t11+t41+t22+t52)**2
g2 = (t21+t51+t12+t42)**2
g3 = (t31+t61)**2
g6 = (t32+t62)**2

fsum221 = con*(g1+g2+g3+g6)

# %%
##--------------------- f = |F=1, J=3/2, L=2, mf=1> -----------------------------##
sf = S(1)/2
ff = 2
mff = 0
jf = S(3)/2
lf = 2

wf = 2*np.pi*(146.11656100000005e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t41 = mu11*mu12/(wl-w)
t42 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t51 = mu11*mu12/(wl-w)
t52 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t61 = mu11*mu12/(wl-w)
t62 = mu21*mu22/(wl+w-wf)


g1 = (t11+t41+t32+t62)**2
g2 = (t21+t51+t22+t52)**2
g3 = (t31+t61+t12+t42)**2

ftest1222 = con*(t31+t61)**2
ftest2222 = con*(t31**2+t61**2)
ftest3222 = con*(t31**2+t61**2+t12**2+t42**2)
fsum222 = con*(g1+g2+g3)

# %%
##--------------------- f = |F=1, J=3/2, L=2, mf=1> -----------------------------##
sf = S(1)/2
ff = 2
mff = 1
jf = S(3)/2
lf = 2

wf = 2*np.pi*(146.11656100000005e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t41 = mu11*mu12/(wl-w)
t42 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t51 = mu11*mu12/(wl-w)
t52 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x
#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t61 = mu11*mu12/(wl-w)
t62 = mu21*mu22/(wl+w-wf)


g1 = (t11+t41)**2
g2 = (t21+t51+t32+t62)**2
g3 = (t31+t61+t22+t52)**2
ftest1223 = con*(t31+t61)**2
ftest2223 = con*(t31**2+t61**2)
ftest3223 = con*(t31**2+t61**2+t22**2+t52**2)
fsum223 = con*(g1+g2+g3)

# %%
##--------------------- f = |F=1, J=3/2, L=2, mf=2> -----------------------------##
sf = S(1)/2
ff = 2
mff = 2
jf = S(3)/2
lf = 2

wf = 2*np.pi*(146.11656100000005e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x
#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1pd1
gli = gam1ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x
#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x
##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t41 = mu11*mu12/(wl-w)
t42 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t51 = mu11*mu12/(wl-w)
t52 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd1
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x
#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x
##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t61 = mu11*mu12/(wl-w)
t62 = mu21*mu22/(wl+w-wf)


g1 = (t11+t41)**2
g2 = (t21+t51)**2
g3 = (t31+t61+t32+t62)**2
g5 = (t22+t52)**2
g6 = (t12+t42)**2
ftest1224 = con*(t31+t61)**2
ftest2224 = con*(t31**2+t61**2)
ftest3224 = con*(t31**2+t61**2+t32**2+t62**2)
fsum224 = con*(g1+g2+g3+g5+g6)


fsum224 = con*(g1+g2+g3+g5+g6)

# %%
print(float(fsum220))
print(float(fsum221))
print(float(fsum222))
print(float(fsum223))
print(float(fsum224))

print('d_3/2 F=2 scatter', float(fsum220+fsum221+fsum222+fsum223+fsum224))

# print('d_3/2 test 1--no counterrotating F=1 scatter', float(ftest1222+ftest1223+ftest1224))
# print('d_3/2 F=1 test 2 -- no interference no counterrotatting scatter', float(ftest2222+ftest2223+ftest2224))
# print('d_3/2 F=1 test 3 -- no interference scatter', float(ftest3222+ftest3223+ftest3224))
# Out:
# 0.0
# 0.08051197093844197
# 0.12525620385103886
# 0.08051197093844197
# 0.0
# d_3/2 F=2 scatter 0.28628014572792276

# %%
# print(float(fsum210+fsum211+fsum212+fsum220+fsum221+fsum222+fsum223+fsum224))
# print('test 1--no counterrotating F=1 scatter', float(ftest1211+ftest2212+ftest1222+ftest1223+ftest1224))
# print('test 2 -- no interference no counterrotatting scatter', float(ftest2211+ftest2212+ftest2222+ftest2223+ftest2224))
# print('d_3/2 F=1 test 3 -- no interference scatter', float(ftest3211+ftest3212+ftest3222+ftest3223+ftest3224))

# %%
##--------------------- f = |F=2, J=5/2, L=2, mf=2> -----------------------------##
sf = S(1)/2
ff = 2
mff = -2
jf = S(5)/2
lf = 2

wf = 2*np.pi*(170.1732188978e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)


g1 = (t11+t12)**2
g2 = (t21)**2
g3 = (t31)**2
g5 = (t22)**2
g6 = (t32)**2
fsum320 = con*(g1+g2+g3+g5+g6)

# %%
##--------------------- f = |F=2, J=5/2, L=2, mf=2> -----------------------------##
sf = S(1)/2
ff = 2
mff = -1
jf = S(5)/2
lf = 2

wf = 2*np.pi*(170.1732188978e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)


g1 = (t11+t22)**2
g2 = (t21+t12)**2
g3 = (t31)**2


fsum321 = con*(g1+g2+g3)

# %%
##--------------------- f = |F=2, J=5/2, L=2, mf=2> -----------------------------##
sf = S(1)/2
ff = 2
mff = 0
jf = S(5)/2
lf = 2

wf = 2*np.pi*(170.1732188978e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x
#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)


g1 = (t11+t32)**2
g2 = (t21+t22)**2
g3 = (t31+t12)**2
fsum322 = con*(g1+g2+g3)

# %%
##--------------------- f = |F=2, J=5/2, L=2, mf=2> -----------------------------##
sf = S(1)/2
ff = 2
mff = 1
jf = S(5)/2
lf = 2

wf = 2*np.pi*(170.1732188978e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x
#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)


g1 = (t11)**2
g2 = (t21+t32)**2
g3 = (t31+t22)**2


fsum323 = con*(g1+g2+g3)

# %%
##--------------------- f = |F=2, J=5/2, L=2, mf=2> -----------------------------##
sf = S(1)/2
ff = 2
mff = 2
jf = S(5)/2
lf = 2

wf = 2*np.pi*(170.1732188978e12)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t11 = mu11*mu12/(wl-w)
t12 = mu21*mu22/(wl+w-wf)


##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x


t21 = mu11*mu12/(wl-w)
t22 = mu21*mu22/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2pd2
gli = gam2ps

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu11 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x
#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu12 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x
##l --> f e_q ##

c1 = wigner_3j(fl, 1, ff, -mfl,  -q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jl+S(1)/2+ff+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu21 = np.sqrt(glf*3*sc.c**2/(4*a*(wl-wf)**3))*x

#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(jl+S(1)/2+fi+1)
x = c1*c2*sympy.sqrt(2*jl+1)
mu22 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t31 = mu11*mu12/(wl-w)
t32 = mu21*mu22/(wl+w-wf)


g1 = (t11)**2
g2 = (t21)**2
g3 = (t31+t32)**2
g5 = (t22)**2
g6 = (t12)**2
fsum324 = con*(g1+g2+g3+g5+g6)

# %%
print(float(fsum320))
print(float(fsum321))
print(float(fsum322))
print(float(fsum323))
print(float(fsum324))

print('d_5/2 F=2 scatter', float(fsum320+fsum321+fsum322+fsum323+fsum324))
# Out:
# 0.0
# 0.03899632784893908
# 0.07475111731729293
# 0.03899632784893908
# 0.0
# d_5/2 F=2 scatter 0.1527437730151711

# %%
print('intensity', I)
print('s scatter', float(fsum10+fsum11+fsum12))
print('d_3/2 F=1 scatter', float(fsum210+fsum211+fsum212))
print('d_3/2 F=2 scatter', float(fsum220+fsum221+fsum222+fsum223+fsum224))
print('d_5/2 F=2 scatter', float(fsum320+fsum321+fsum322+fsum323+fsum324))
print('total scatter', float(fsum10+fsum11+fsum12+fsum210+fsum211+fsum212+fsum220+fsum221+fsum222+fsum223+fsum224+fsum320+fsum321+fsum322+fsum323+fsum324))
# Out:
# intensity 636619772.3675814
# s scatter 0.2836631422044677
# d_3/2 F=1 scatter 0.1752050327608189
# d_3/2 F=2 scatter 0.28628014572792276
# d_5/2 F=2 scatter 0.1527437730151711
# total scatter 0.8978920937083805
