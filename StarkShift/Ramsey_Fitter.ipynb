# %%
###Lorentzian data fitting


import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np



data1 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_01.dir/00391 - Ramsey_prob.csv', delimiter = ',')
data2 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_01.dir/00394 - Ramsey_prob.csv', delimiter = ',')
data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_01.dir/00397 - Ramsey_prob.csv', delimiter = ',')
data4 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_01.dir/00400 - Ramsey_prob.csv', delimiter = ',')
data5 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_01.dir/00403 - Ramsey_prob.csv', delimiter = ',')
data6 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_01.dir/00406 - Ramsey_prob.csv', delimiter = ',')
data7 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_01.dir/00409 - Ramsey_prob.csv', delimiter = ',')
data8 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_01.dir/00412 - Ramsey_prob.csv', delimiter = ',')
data9 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_01.dir/00415 - Ramsey_prob.csv', delimiter = ',')
data10 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_01.dir/00418 - Ramsey_prob.csv', delimiter = ',')


freq = data10[:,0]*1e-6
prob = 1-data10[:,1]

def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    y =  np.sin( d/2*x)**2
    return y

guess = [np.pi*2*450]
popt, pcov = curve_fit(func, freq, prob, p0=guess)
print(popt/(np.pi*2))
x_fit = np.linspace(freq[0],freq[-1],100000)
fit = func(x_fit, *popt)
# Out:
# [472.078847]

# %%
peak = np.zeros(10)
peak = (472.37295527,472.71715028,471.13848436,472.07505596,470.02973002,473.45308938,471.01611916,473.05539057,471.39251861,472.078847)

# %%
print('mean', (np.mean(peak)))
print('sd', (np.std(peak)))
# Out:
# mean 471.9329340609999
# sd 0.9902938019804383

# %%
###Lorentzian data fitting


import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np



data = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/07.dir/2022_07_28.dir/00478 - MicrowaveSweep_prob.csv', delimiter = ',')


freq = data[:,0]
prob = data[:,1]

def func(x, *params):
    y = np.zeros_like(x)
    ctr = params[0]
    amp = params[1]
    wid = params[2]
    y = y + amp * np.exp( -((x - ctr)/wid)**2)
    return y


guess = [freq[0],.3,.03]
popt, pcov = curve_fit(func, freq, prob, p0=guess)
x_fit = np.linspace(freq[0],freq[-1],100000)
fit = func(x_fit, *popt)

print(popt)
##Plotting Results###
plt.rcParams['figure.figsize'] = [12, 8]
fig = plt.figure()
ax = fig.gca()
ax.ticklabel_format(useOffset=False)
ax.patch.set_facecolor('lightgrey')
ax.patch.set_alpha(.5)
plt.xlabel("Freq")
plt.ylabel("$F=1$ Probability ")
plt.plot(freq,prob,'o')
plt.plot(x_fit,fit)



plt.grid()
plt.show()
# Out:
# [9.91821503e+03 7.27526098e-01 8.22078847e-03]

# %%
(9.93266135-9.93267658)*1e9
# Out:
# -15230.000000698852

# %%
peak = np.zeros(10)
peak = (484.63393373,483.6183827,482.54793177,482.54793177,482.54793177,484.72379901,482.73981228,484.56207265,485.14873186,486.69701437)

# %%
print('mean', (np.mean(peak)))
print('standard error', (np.std(peak)))
# Out:
# mean 483.97675419100005
# standard error 1.337496230036393

# %%
print('mean shift', 483.97675419100005-471.9329340609999)
print('standard error', (np.std(peak))/np.sqrt(10))
# Out:
# mean shift 12.043820130000142
# standard error 0.4229534448803513

# %%
peak = np.zeros(10)
peak = (557.65618767,559.33507835,558.39943812,559.72428942,557.15505766,557.96073799,557.24659384,558.54301467,559.25311609)

# %%
print('mean', (np.mean(peak)))
print('sd', (np.std(peak)))
# Out:
# mean 558.3637237566667
# sd 0.8813478293179114

# %%
498.59184706-559.25311609
# Out:
# -60.66126903000003

# %%
(5650.24-5649.911)*1e3
# Out:
# 328.9999999997235

# %%
318000/60.6
# Out:
# 5247.524752475248

# %%
 print('ratio of shift', 63.28014670907578*1e3/12.043820130000142)
# Out:
# ratio of shift 5254.159064651776

# %%
###Lorentzian data fitting


import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np



data1 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_06.dir/00271 - Ramsey_prob.csv', delimiter = ',')


freq = data1[:,0]*1e-6
prob = 1-data1[:,1]

def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    y =  np.sin( d/2*x)**2
    return y

guess = [np.pi*2*450]
popt, pcov = curve_fit(func, freq, prob, p0=guess)
print(popt/(np.pi*2))
x_fit = np.linspace(freq[0],freq[-1],100000)
fit = func(x_fit, *popt)
# Out:
# [387.38333665]

# %%
peak = np.zeros(10)
peak = (512.01606826,512.89508109,510.06422402,511.53930059,521.92081896)
np.mean(peak)
# Out:
# 513.687098584

# %%
peak = np.zeros(10)
peak = (383.49155765,383.49155765,377.03689726,380.01712713,387.38333665)
np.mean(peak)
np.std(peak/np.sqrt(5))
# Out:
# 1.5695913474998213

# %%
print('mean', 513.687098584-382.284095268)
print('standard error', (np.std(peak))/np.sqrt(10))
# Out:
# mean 131.40300331599997
# standard error 1.1098686855088566

# %%
513.687098584-382.284095268
# Out:
# 131.40300331599997

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np



data1 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/05.dir/2022_05_07.dir/00210 - Ramsey_prob.csv', delimiter = ',')
data = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/05.dir/2022_05_07.dir/00204 - Ramsey_prob.csv', delimiter = ',')


freq = data1[:,0]*1e-6
prob = 1-data1[:,1]

def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    y =  np.sin( d/2*x)**2
    return y

guess = [np.pi*2*650]
popt, pcov = curve_fit(func, freq, prob, p0=guess)
print(popt/(np.pi*2))
x_fit = np.linspace(freq[0],freq[-1],100000)
fit = func(x_fit, *popt)
print('cov',pcov)

freq2 = data2[:,0]*1e-6
prob2 = 1-data2[:,1]

guess = [np.pi*2*500]
popt2, pcov2 = curve_fit(func, freq2, prob2, p0=guess)
print(popt2/(np.pi*2))
x_fit2 = np.linspace(freq2[0],freq2[-1],100000)
fit2 = func(x_fit2, *popt2)


##Plotting Results###
plt.rcParams['figure.figsize'] = [12, 8]
fig = plt.figure()
fig.suptitle(' Ramsey', fontsize=20)
ax = fig.gca()
ax.ticklabel_format(useOffset=False)
ax.patch.set_facecolor('lightgrey')
ax.patch.set_alpha(.5)
plt.xlabel("Time (us)")
plt.ylabel("$F=1$ Probability ")

plt.plot(freq,prob,'o', color ='red',label = 'No 532')
plt.plot(x_fit,fit, color ='crimson',label = 'No 532')
plt.plot(freq2,prob2,'o', color ='blue',label = 'With 532')
plt.plot(x_fit2,fit2, color ='royalblue',label = 'With 532')


plt.legend(loc=(1.04,.51))

plt.grid()
plt.show()
# Out:
# [772.94752023]
# cov [[351.37533168]]
# [472.71715275]

# %%
###Lorentzian data fitting


import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np



data1 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_15.dir/00559 - Ramsey_prob.csv', delimiter = ',')
data2 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_15.dir/00562 - Ramsey_prob.csv', delimiter = ',')
data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_15.dir/00565 - Ramsey_prob.csv', delimiter = ',')
data4 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_15.dir/00568 - Ramsey_prob.csv', delimiter = ',')
data5 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_15.dir/00577 - Ramsey_prob.csv', delimiter = ',')

data= [data1,data2,data3,data4,data5]
freq = np.zeros((len(data),len(data[0])))
prob = np.zeros((len(data),len(data[0])))
po = np.zeros(len(data))
pc = np.zeros(len(data))

j=0
for i in data:
    f = data[j][:,0]*1e-6
    freq[j] = f 
    p = 1-data[j][:,1]
    prob[j] = p
    j +=1
    
    
def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    y =  np.sin(d/2*x)**2
    return y

guess = [np.pi*2*520]

for i in range(len(freq)):
    popt, pcov = curve_fit(func, freq[i], prob[i], p0=guess)
    po[i] = popt 
    pc[i] = pcov
    
print(po/(np.pi*2))
print(pc/(np.pi*2))
print(np.mean(po/(np.pi*2)))
print(np.std(po/(np.pi*2)))
# Out:
# [518.28239675 518.64146734 518.00693319 520.46966759 519.34382707]
# [8.5702798  5.51277094 2.79763722 4.68716378 4.48534732]
# 518.9488583887857
# 0.882580798896306

# %%
x = np.zeros((len(data1),5))
std = np.zeros(len(data1))
ydata = np.zeros(len(data1))

for i in range(len(data1)):
    x[i] = [data1[i,1],data2[i,1],data3[i,1],data4[i,1],data5[i,1]]
for i in range(len(data1)):
    std[i] = np.std(x[i])/np.sqrt(2)
for i in range(len(data1)):
    ydata[i] = 1-np.mean(x[i])

    
def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    y =  np.sin(d/2*x)**2
    return y

guess = [np.pi*2*450]
popt, pcov = curve_fit(func, freq[1], ydata, p0=guess, sigma = std)
x_fit = np.linspace(freq[1][0],freq[1][-1],100000)
fit = func(x_fit, *popt)


print(popt/(np.pi*2))
print('cov',pcov/(np.pi*2))


##Plotting Results###
plt.rcParams['figure.figsize'] = [12, 8]
fig = plt.figure()
fig.suptitle(' Ramsey', fontsize=20)
ax = fig.gca()
ax.ticklabel_format(useOffset=False)
ax.patch.set_facecolor('lightgrey')
ax.patch.set_alpha(.5)
plt.xlabel("Time (us)")
plt.ylabel("$F=1$ Probability ")

plt.errorbar(freq[1],ydata, yerr=std, fmt='o',color ='blue',label = 'No 532', capsize=2)
plt.plot(x_fit,fit, color ='crimson',label = 'No 532')



plt.legend(loc=(1.04,.51))

plt.grid()
plt.show()
# Out:
# [518.52322844]
# cov [[1.42865385]]

# %%
###Lorentzian data fitting


import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np



data1 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_15.dir/00664 - Ramsey_prob.csv', delimiter = ',')
data2 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_15.dir/00646 - Ramsey_prob.csv', delimiter = ',')
data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_15.dir/00649 - Ramsey_prob.csv', delimiter = ',')
data4 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_15.dir/00652 - Ramsey_prob.csv', delimiter = ',')
data5 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_15.dir/00661 - Ramsey_prob.csv', delimiter = ',')

data= [data1,data2,data3,data4,data5]
freq = np.zeros((len(data),len(data[0])))
prob = np.zeros((len(data),len(data[0])))
po2 = np.zeros(len(data))
pc2 = np.zeros(len(data))

j=0
for i in data:
    f = data[j][:,0]*1e-6
    freq[j] = f 
    p = 1-data[j][:,1]
    prob[j] = p
    j +=1
    
    
def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    y =  np.sin(d/2*x)**2
    return y

guess = [np.pi*2*520]

for i in range(len(freq)):
    popt, pcov = curve_fit(func, freq[i], prob[i], p0=guess)
    po2[i] = popt
    pc2[i] = pcov
    
print(po2/(np.pi*2))
print(pc2/(np.pi*2))
print(np.mean(po2/(np.pi*2)))
print(np.std(po2/(np.pi*2))/np.sqrt(5))
# Out:
# [626.62593577 626.34641633 619.22876714 625.62441165 625.76756285]
# [18.75697091 15.50944397 20.14642033 22.60198991 13.43461035]
# 624.7186187489076
# 1.2384958363981937

# %%
x2 = np.zeros((len(data1),5))
std2 = np.zeros(len(data1))
ydata2 = np.zeros(len(data1))

for i in range(len(data1)):
    x2[i] = [data1[i,1],data2[i,1],data3[i,1],data4[i,1],data5[i,1]]
for i in range(len(data1)):
    std2[i] = np.std(x2[i])/np.sqrt(5)
for i in range(len(data1)):
    ydata2[i] = 1-np.mean(x2[i])

    
def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    y =  np.sin(d/2*x)**2
    return y

guess = [np.pi*2*600]
popt2, pcov2 = curve_fit(func, freq[1], ydata2, p0=guess, sigma = std2)
x_fit2 = np.linspace(freq[1][0],freq[1][-1],100000)
fit2 = func(x_fit2, *popt2)


print(popt2/(np.pi*2))
print('cov',pcov2/(np.pi*2))
# Out:
# [627.09675067]
# cov [[12.85211389]]

# %%
##Plotting Results###
plt.rcParams['figure.figsize'] = [12, 8]
fig = plt.figure()
fig.suptitle('Differential Stark Shift Ramsey Measurement', fontsize=20)
ax = fig.gca()
ax.ticklabel_format(useOffset=False)
ax.patch.set_facecolor('lightgrey')
ax.patch.set_alpha(.5)
plt.xlabel("Time (us)")
plt.ylabel("$F=1$ Probability ")

plt.errorbar(freq[1],ydata, yerr=std, fmt='o',color ='royalblue',label = 'No 532', capsize=2)
plt.plot(x_fit,fit, color ='blue',label = 'No 532')
plt.errorbar(freq[1],ydata2, yerr=std2, fmt='o',color ='green',label = 'With 532', capsize=2)
plt.plot(x_fit,fit2, color ='green',label = 'With 532')


plt.legend(loc=(1.04,.51))

plt.grid()
plt.show()

# %%
print('No 532 Mean Detuning', np.mean(po/(np.pi*2)), 'Hz')
print('No 532 standard error', np.std(po/(np.pi*2))/np.sqrt(5),'Hz')

print('With 532 Mean Detuning', np.mean(po2/(np.pi*2)),'Hz')
print('With 532 standard error', np.std(po2/(np.pi*2))/np.sqrt(5),'Hz')

print('Mean Stark Shift', -np.mean(po/(np.pi*2))+np.mean(po2/(np.pi*2)),'Hz')
# Out:
# No 532 Mean Detuning 518.9488583887857 Hz
# No 532 standard error 0.3947021323936423 Hz
# With 532 Mean Detuning 624.7186187489076 Hz
# With 532 standard error 1.2384958363981937 Hz
# Mean Stark Shift 105.76976036012195 Hz

# %%
557.45981755-518.94885
# Out:
# 38.51096755000003

# %%
###Lorentzian data fitting


import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np



data1 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_16.dir/00085 - Ramsey_prob.csv', delimiter = ',')
data2 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_16.dir/00088 - Ramsey_prob.csv', delimiter = ',')
data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_16.dir/00091 - Ramsey_prob.csv', delimiter = ',')
data4 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_16.dir/00094 - Ramsey_prob.csv', delimiter = ',')
data5 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_16.dir/00097 - Ramsey_prob.csv', delimiter = ',')

data= [data1,data2,data3,data4,data5]
freq = np.zeros((len(data),len(data[0])))
prob = np.zeros((len(data),len(data[0])))
po = np.zeros(len(data))
pc = np.zeros(len(data))

j=0
for i in data:
    f = data[j][:,0]*1e-6
    freq[j] = f 
    p = 1-data[j][:,1]
    prob[j] = p
    j +=1
    
    
def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    y =  np.sin(d/2*x)**2
    return y

guess = [np.pi*2*520]

for i in range(len(freq)):
    popt, pcov = curve_fit(func, freq[i], prob[i], p0=guess)
    po[i] = popt 
    pc[i] = pcov
    
print(po/(np.pi*2))
print(pc/(np.pi*2))
print(np.mean(po/(np.pi*2)))
print(np.std(po/(np.pi*2))/np.sqrt(5))
# Out:
# [557.45982201 557.21340662 555.21501399 557.36627322 555.58677251]
# [6.98727239 9.83841353 6.33254493 8.00656502 9.51725213]
# 556.5682576680085
# 0.43092990271906184

# %%
###Lorentzian data fitting


import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np



data1 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_16.dir/00148 - Ramsey_prob.csv', delimiter = ',')
data2 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_16.dir/00156 - Ramsey_prob.csv', delimiter = ',')
data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_16.dir/00159 - Ramsey_prob.csv', delimiter = ',')
data4 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_16.dir/00162 - Ramsey_prob.csv', delimiter = ',')
data5 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/02.dir/2022_02_16.dir/00165 - Ramsey_prob.csv', delimiter = ',')

data= [data1,data2,data3,data4,data5]
freq = np.zeros((len(data),len(data[0])))
prob = np.zeros((len(data),len(data[0])))
po = np.zeros(len(data))
pc = np.zeros(len(data))

j=0
for i in data:
    f = data[j][:,0]*1e-6
    freq[j] = f 
    p = 1-data[j][:,1]
    prob[j] = p
    j +=1
    
    
def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    y =  np.sin(d/2*x)**2
    return y

guess = [np.pi*2*520]

for i in range(len(freq)):
    popt, pcov = curve_fit(func, freq[i], prob[i], p0=guess)
    po[i] = popt 
    pc[i] = pcov
    
print(po/(np.pi*2))
print(pc/(np.pi*2))
print(np.mean(po/(np.pi*2)))
print(np.std(po/(np.pi*2))/np.sqrt(5))
# Out:
# [626.54577887 616.67537021 617.39124389 617.19665514 618.60473646]
# [ 7.84593407 19.65135815 17.13293581 16.88372046 23.67886196]
# 619.2827569147131
# 1.6485060773673998

# %%
###Lorentzian data fitting


import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np



data1 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/04.dir/2022_04_13.dir/00109 - Ramsey_prob.csv', delimiter = ',')
data2 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/04.dir/2022_04_13.dir/00112 - Ramsey_prob.csv', delimiter = ',')
data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/04.dir/2022_04_13.dir/00115 - Ramsey_prob.csv', delimiter = ',')
data4 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/04.dir/2022_04_13.dir/00118 - Ramsey_prob.csv', delimiter = ',')
data5 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/04.dir/2022_04_13.dir/00121 - Ramsey_prob.csv', delimiter = ',')

data= [data1,data2,data3,data4,data5]
freq = np.zeros((len(data),len(data[0])))
prob = np.zeros((len(data),len(data[0])))
po = np.zeros(len(data))
pc = np.zeros(len(data))

j=0
for i in data:
    f = data[j][:,0]*1e-6
    freq[j] = f 
    p = 1-data[j][:,1]
    prob[j] = p
    j +=1
    
    
def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    y =  np.sin(d/2*x)**2
    return y

guess = [np.pi*2*600]

for i in range(len(freq)):
    popt, pcov = curve_fit(func, freq[i], prob[i], p0=guess)
    po[i] = popt 
    pc[i] = pcov
    
print(po/(np.pi*2))
print(pc/(np.pi*2))
print(np.mean(po/(np.pi*2)))
print(np.std(po/(np.pi*2))/np.sqrt(5))
# Out:
# [519.90557258 519.24000522 519.58526997 520.69481527 520.39901064]
# [4.54330517 4.88255191 3.16453288 3.03212589 3.36812219]
# 519.9649347334262
# 0.2361643067668239

# %%
###Lorentzian data fitting


import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np



data1 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/05.dir/2022_05_10.dir/00398 - Ramsey_prob.csv', delimiter = ',')
data2 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/05.dir/2022_05_10.dir/00401 - Ramsey_prob.csv', delimiter = ',')
data3 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/05.dir/2022_05_10.dir/00404 - Ramsey_prob.csv', delimiter = ',')
data4 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/05.dir/2022_05_10.dir/00407 - Ramsey_prob.csv', delimiter = ',')
data5 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/05.dir/2022_05_10.dir/00410 - Ramsey_prob.csv', delimiter = ',')

data= [data1,data2,data3,data4,data5]
freq = np.zeros((len(data),len(data[0])))
prob = np.zeros((len(data),len(data[0])))
po = np.zeros(len(data))
pc = np.zeros(len(data))

j=0
for i in data:
    f = data[j][:,0]*1e-6
    freq[j] = f 
    p = 1-data[j][:,1]
    prob[j] = p
    j +=1
    
    
def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    p = params[1]
    y =  np.sin(d/2*x+p)**2
    return y

guess = [np.pi*2*800,0]

for i in range(len(freq)):
    popt, pcov = curve_fit(func, freq[i], prob[i], p0=guess)
    po[i] = popt[0] 
    pc[i] = pcov[0,0]
    
print(po/(np.pi*2))
print(pc/(np.pi*2))
print(np.mean(po/(np.pi*2)))
print(np.std(po/(np.pi*2))/np.sqrt(5))
# Out:
# [958.71045355 947.34717598 953.09977847 953.74826828 953.63557676]
# [250.53620397 132.45948187 125.95095686  97.82849287 130.62787438]
# 953.3082506102573
# 1.6132256633157067

# %%
516.5845184732359-559.5351082192673
# Out:
# -42.95058974603137

# %%
###Lorentzian data fitting


import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np



data1 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/08.dir/2022_08_31.dir/00296 - Ramsey_prob.csv', delimiter = ',')



freq = data1[:,0]*1e-6
prob = data1[:,1]

def func(x, *params):
    y = np.zeros_like(x)
    d = params[0]
    k = params[1]
    y = .5+np.exp(k*x)*(.5-np.sin(d/2*x)**2)
#     y = 1-np.sin(d/2*x)**2
    return y

guess = [1.5*np.pi*1000,-50]
popt, pcov = curve_fit(func, freq, prob, p0=guess)
print(popt[0]/(np.pi*2), popt[1])
x_fit = np.linspace(freq[0],freq[-1],100000)
fit = func(x_fit, *popt)
##Plotting Results###
plt.rcParams['figure.figsize'] = [12, 8]
fig = plt.figure()
fig.suptitle(' Ramsey', fontsize=20)
ax = fig.gca()
ax.ticklabel_format(useOffset=False)
ax.patch.set_facecolor('lightgrey')
ax.patch.set_alpha(.5)
plt.xlabel("Time (us)")
plt.ylabel("$F=1$ Probability ")


plt.plot(freq,prob,'o', color ='blue',label = 'With 532')
plt.plot(x_fit,fit, color ='royalblue',label = 'With 532')


plt.legend(loc=(1.04,.51))

plt.grid()
plt.show()
# Out:
# 854.5082677024905 -2.4322087112541073

# %%
614.106574336171-854.5082677024905
# Out:
# -240.40169336631948

# %%
1.256/431
# Out:
# 0.00291415313225058

# %%
458.3000/123
# Out:
# 3.7260162601626017

# %%
###Lorentzian data fitting


import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np

data1 = np.loadtxt('Z:/Group_Share/Barium/Data/2022.dir/08.dir/2022_08_17.dir/00330 - Ramsey_prob.csv', delimiter = ',')
print('mean', np.mean(data1[:,1]))
time = [.0023]
prob = [np.mean(data1[:,1])]
t=time[0]
n=-3
k=-61.45964232979077
def func(x, *params):
    t = time[0]
    y = np.zeros_like(x)
    d = params[0]
    y =  .5 + np.exp(k*x)*(.5-np.sin((n*np.pi/t+d)*x)**2)
    return y


guess = [1]
popt, pcov = curve_fit(func, time, prob, p0=guess)
x_fit = np.linspace(0,.0023,100000)
fit = func(x_fit, *popt)
freq = ((n*np.pi)/(t)+popt)/(np.pi)
print(freq)

##Plotting Results###
plt.rcParams['figure.figsize'] = [12, 8]
fig = plt.figure()
fig.suptitle(' Ramsey', fontsize=20)
ax = fig.gca()
ax.ticklabel_format(useOffset=False)
ax.patch.set_facecolor('lightgrey')
ax.patch.set_alpha(.5)
plt.xlabel("Time (us)")
plt.ylabel("$F=1$ Probability ")


plt.plot(time,prob,'o', color ='blue')
plt.plot(x_fit,fit, color ='royalblue')
plt.plot(x_fit,1-np.sin(x_fit*(popt+n*np.pi/t))**2, color ='red')



plt.grid()
plt.show()
# Out:
# mean 0.6421875
# [-1218.74437365]
# c:\users\barium133\appdata\local\programs\python\python39\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
327.27-804.03
# Out:
# -476.76

# %%
414/476
# Out:
# 0.8697478991596639

# %%
70*/2
# Out:
# 301.0

# %%
5651.866-5649.477
# Out:
# 2.3890000000001237

# %%
5649.54+1.975
# Out:
# 5651.515

# %%
72/5.2
# Out:
# 13.846153846153845

# %%
2389000/373
# Out:
# 6404.825737265415
