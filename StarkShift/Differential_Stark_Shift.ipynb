# %%
import sympy
from sympy import S
from sympy.physics.wigner import wigner_3j
from sympy.physics.wigner import wigner_6j
import numpy as np
import scipy.constants as sc

I = 2*.04/(np.pi*(10e-6)**2)
E = np.sqrt(2*I/(sc.c*sc.epsilon_0))
l = 563e12
gam1 =2*np.pi*15.2e6
a = 1/(4*np.pi*sc.epsilon_0*sc.hbar*sc.c)
qf  = 9.9254644e9

# %%
###differential

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1
f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(607.429890e12-1.815e9)
mu = np.sqrt(gam1*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss011 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w02 = 2*np.pi*(607.429890e12-qf-1.815e9)
mu2 = np.sqrt(gam1*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss001 = W2**2/(4*d2)/(2*np.pi)




gam2=2*np.pi*18.8e6

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w0 = 2*np.pi*(658.118271e12+625e6)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss111 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

print('hi',x)
w02 = 2*np.pi*(658.118271e12-qf+625e6)
mu2 = np.sqrt(gam2*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss101 = W2**2/(4*d2)/(2*np.pi)






A=2*np.pi*18.8e6

s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(658.118271e12)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss112 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w02 = 2*np.pi*(658.118271e12-qf)
mu2 = np.sqrt(A*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss102 = W2**2/(4*d2)/(2*np.pi)



print(ss011)
print(ss111)
print(ss112)
print(ss001)
print(ss101)
print(ss102)
print(ss011-ss001)
((ss011+ss111+ss112)-(ss001+ss101+ss102))
# Out:
# hi sqrt(6)/3
# 333892.967185297
# 75832.2136391312
# 227498.783894903
# 333983.949062910
# 303374.235481903
# 0
# -90.9818776125903
# -134.219825481065

# %%
##optical

import scipy.constants as sc
import numpy as np
from sympy import *

I = 2*.40/(np.pi*(40e-6)**2)

E = np.sqrt(2*I/(sc.c*sc.epsilon_0))

w0 = 2*np.pi*607.429e12
A=2*np.pi*15.1e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(607.429-563)*1e12
ss = W**2/(4*d)/(2*np.pi)


w0 = 2*np.pi*658.118e12
A=2*np.pi*18.8e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(658.118-563)*1e12
ss2 = W**2/(4*d)/(2*np.pi)



w0 = 2*np.pi*658.118e12
A=2*np.pi*18.8e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(658.118-563)*1e12
ss3 = W**2/(4*d)/(2*np.pi)


w0 = 2*np.pi*489.989e12
A=2*np.pi*5.9e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 3
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*sympy.sqrt(2*j1+1)*x

W= E/sc.hbar*mu
d = 2*np.pi*(489.989-563)*1e12
ss4 = W**2/(4*d)/(2*np.pi)


##F7/2 shift
mu = 3.794062882e-29

s = S(1)/2
f1 = 3
mf1 = 1
j1 = S(7)/2
l1 = 1

f2 = 3
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = mu*x

W= E/sc.hbar*mu
d = 2*np.pi*(1283.358125-563)*1e12
ss5 = W**2/(4*d)/(2*np.pi)

mu = 3.794062882e-29

s = S(1)/2
f1 = 4
mf1 = 1
j1 = S(7)/2
l1 = 1

f2 = 3
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = mu*x

W= E/sc.hbar*mu
ss6 = W**2/(4*d)/(2*np.pi)

print(ss5/1e3)
print(ss6/1e3)
print(ss4/1e3)
print('optical stark shift in khz', (ss+ss2+ss3-ss5-ss6-ss4)/1e3)
print('Intensity', I)
# Out:
# 0.406097164345520
# 6.09145746518280
# -37.5621545109604
# optical stark shift in khz 427.952620255504
# Intensity 159154943.09189534

# %%
##optical pi light

import scipy.constants as sc
import numpy as np
from sympy import *

I = 2*.11/(np.pi*(29.3e-6)**2)

E = np.sqrt(2*I/(sc.c*sc.epsilon_0))

w0 = 2*np.pi*607.429e12
A=2*np.pi*15.1e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 0
mf1 = 0
j1 = S(1)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(607.429-563)*1e12
ss = W**2/(4*d)/(2*np.pi)


w0 = 2*np.pi*658.118e12
A=2*np.pi*18.8e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 0
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(658.118-563)*1e12
ss2 = W**2/(4*d)/(2*np.pi)



w0 = 2*np.pi*658.118e12
A=2*np.pi*18.8e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 2
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(658.118-563)*1e12
ss3 = W**2/(4*d)/(2*np.pi)


w0 = 2*np.pi*489.989e12
A=2*np.pi*5.9e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 2
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 3
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)

mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(489.989-563)*1e12
ss4 = W**2/(4*d)/(2*np.pi)



##F7/2 shift
mu = 3.794062882e-29

s = S(1)/2
f1 = 3
mf1 = 0
j1 = S(7)/2
l1 = 1

f2 = 3
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = mu*x

W= E/sc.hbar*mu
d = 2*np.pi*(1283.358125-563)*1e12
ss5 = W**2/(4*d)/(2*np.pi)

mu = 3.794062882e-29

s = S(1)/2
f1 = 4
mf1 = 0
j1 = S(7)/2
l1 = 3

f2 = 3
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = mu*x

W= E/sc.hbar*mu
ss6 = W**2/(4*d)/(2*np.pi)

print(ss5/1e3)
print(ss6/1e3)
print(ss4/1e3)
print((ss+ss2+ss3-ss5-ss6-ss4)/1e3)
# Out:
# 0
# 4.99526617140408
# -57.7549464227513
# 256.175828330640

# %%
import sympy
from sympy import S
from sympy.physics.wigner import wigner_3j
from sympy.physics.wigner import wigner_6j
import numpy as np
import scipy.constants as sc

I = 2*1/(np.pi*(100e-6)**2)
E = np.sqrt(2*I/(sc.c*sc.epsilon_0))
l = 563e12
a = 1/(4*np.pi*sc.epsilon_0*sc.hbar*sc.c)

s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(1)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0
gam1 = 20.1028e6*2*np.pi*.76
c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(607.595e12-1.815e9)
mu = np.sqrt(gam1*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss011 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(1)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2
print(x)
w02 = 2*np.pi*(607.429890e12-9.9254644e9-1.815e9)
mu2 = np.sqrt(gam1*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss001 = W2**2/(4*d2)/(2*np.pi)

s = S(1)/2
f1 = 0
mf1 = 0
j1 = S(1)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w02 = 2*np.pi*(607.429890e12-9.9254644e9)
mu2 = np.sqrt(gam1*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss000 = W2**2/(4*d2)/(2*np.pi)

s = S(1)/2
f1 = 0
mf1 = 0
j1 = S(1)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w02 = 2*np.pi*(607.429890e12)
mu2 = np.sqrt(gam1*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss010 = W2**2/(4*d2)/(2*np.pi)


gam2=2*np.pi*18.8e6

s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w0 = 2*np.pi*(658.118271e12+625e6)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss111 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2
print(x)

w02 = 2*np.pi*(658.118271e12-9.9254644e9+625e6)
mu2 = np.sqrt(gam2*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss101 = W2**2/(4*d2)/(2*np.pi)

A=2*np.pi*18.8e6

s = S(1)/2
f1 = 2
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(658.118271e12)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss112 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 2
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w02 = 2*np.pi*(658.118271e12-9.9254644e9)
mu2 = np.sqrt(A*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss102 = W2**2/(4*d2)/(2*np.pi)



print(ss011)
print(ss010)
print(ss111)
print(ss112)
print(ss000)
print(ss001)
print(ss101)
print(ss102)
(ss011+ss010+ss111+ss112)-(ss000+ss001+ss101+ss102)
print('Intensity', I)
print('F=0->P_1/2 F=1', ss001)
print('F=0->P_3/2 F=1', ss101)
print('F=1->P_1/2 F=0', ss010)
print('F=1->P_3/2 F=2', ss112)
print('differential', (ss011+ss010+ss111+ss112)-(ss000+ss001+ss101+ss102))
# Out:
# sqrt(3)/3
# sqrt(6)/3
# 0
# 83898.1147098179
# 0
# 75832.9279649677
# 0
# 83925.1566402733
# 75843.5588704757
# 0
# Intensity 63661977.236758135
# F=0->P_1/2 F=1 83925.1566402733
# F=0->P_3/2 F=1 75843.5588704757
# F=1->P_1/2 F=0 83898.1147098179
# F=1->P_3/2 F=2 75832.9279649677
# differential -37.6728359633998

# %%
s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

I = 2*.11/(np.pi*(29.3e-6)**2)
E = np.sqrt(2*I/(sc.c*sc.epsilon_0))
l = 563e12

gam1 = 6.8e6
c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(1484.121079208e12)
mu = np.sqrt(gam1*3*sc.c**2/(4*a*w0**3))*x
W = E/sc.hbar*mu
d = w0-2*np.pi*l
ss011 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w02 = 2*np.pi*(1484.121079208e12-qf)
mu2 = np.sqrt(gam1*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss001 = W2**2/(4*d2)/(2*np.pi)




gam2=1e7

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w02 = 2*np.pi*(1499.322127311e12)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss111 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w02 = 2*np.pi*(1499.322127311e12-qf)
mu2 = np.sqrt(gam2*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss101 = W2**2/(4*d2)/(2*np.pi)





s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(1499.322127311e12)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss112 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w02 = 2*np.pi*(1499.322127311e12-qf)
mu2 = np.sqrt(gam2*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss102 = W2**2/(4*d2)/(2*np.pi)



print(ss011)
print(ss111)
print(ss112)
print(ss001)
print(ss101)
print(ss102)
(ss011+ss111+ss112)-(ss001+ss101+ss102)
# Out:
# 25.1830042493452
# 18.5169148892244
# 53.0034902179361
# 25.1837808764851
# 70.6734730075545
# 0
# 0.846155472466066

# %%
import sympy
from sympy import S
from sympy.physics.wigner import wigner_3j
from sympy.physics.wigner import wigner_6j
import numpy as np
import scipy.constants as sc

I = 2*.035/(np.pi*(29.3e-6)**2)
E = np.sqrt(2*I/(sc.c*sc.epsilon_0))
l = 563e12
a = 1/(4*np.pi*sc.epsilon_0*sc.hbar*sc.c)

s = S(1)/2
f1 = 0
mf1 = 0
j1 = S(1)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

gam1 = 6.8e6

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(1484.121079208e12)
mu = np.sqrt(gam1*3*sc.c**2/(4*a*w0**3))*x
W = E/sc.hbar*mu
d = w0-2*np.pi*l
ss011 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(1)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w02 = 2*np.pi*(1484.121079208e12-qf)
mu2 = np.sqrt(gam1*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss001 = W2**2/(4*d2)/(2*np.pi)




gam2=1e7

s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w02 = 2*np.pi*(1499.322127311e12)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss111 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w02 = 2*np.pi*(1499.322127311e12-qf)
mu2 = np.sqrt(gam2*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss101 = W2**2/(4*d2)/(2*np.pi)


s = S(1)/2
f1 = 2
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(1499.322127311e12)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss112 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 2
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w02 = 2*np.pi*(1499.322127311e12-qf)
mu2 = np.sqrt(gam2*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss102 = W2**2/(4*d2)/(2*np.pi)



print(ss011)
print(ss111)
print(ss112)
print(ss001)
print(ss101)
print(ss102)
(ss011+ss111+ss112)-(ss001+ss101+ss102)
# Out:
# 8.01277407933711
# 0
# 22.4863291833668
# 8.01302118797255
# 22.4870141387673
# 0
# -0.000932064035957580

# %%
# differential from F=0 mf=0 to F=1 mf=-1  

import sympy
from sympy import S
from sympy.physics.wigner import wigner_3j
from sympy.physics.wigner import wigner_6j
import numpy as np
import scipy.constants as sc

I = 2*.11/(np.pi*(29.3e-6)**2)
E = np.sqrt(2*I/(sc.c*sc.epsilon_0))

l = 563e12
a = 1/(4*np.pi*sc.epsilon_0*sc.hbar*sc.c)
gam1 = 15.1*2*np.pi*1e6
s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(1)/2
l1 = 1
f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(607.429890e12-1.815e9)
mu = np.sqrt(gam1*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss011 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w02 = 2*np.pi*(607.429890e12-qf-1.815e9)
mu2 = np.sqrt(gam1*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss001 = W2**2/(4*d2)/(2*np.pi)


s = S(1)/2
f1 = 0
mf1 = 0
j1 = S(1)/2
l1 = 1
f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(607.429890e12)
mu = np.sqrt(gam1*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss010 = W**2/(4*d)/(2*np.pi)


gam2=2*np.pi*18.8e6

s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(3)/2
l1 = 1
f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w0 = 2*np.pi*(658.118271e12+625e6)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss111 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w02 = 2*np.pi*(658.118271e12-qf+625e6)
mu2 = np.sqrt(gam2*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss101 = W2**2/(4*d2)/(2*np.pi)






A=2*np.pi*18.8e6

s = S(1)/2
f1 = 2
mf1 = 2
j1 = S(3)/2
l1 = 1
f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(658.118271e12)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss112 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2
w02 = 2*np.pi*(658.118271e12-qf)
mu2 = np.sqrt(A*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss102 = W2**2/(4*d2)/(2*np.pi)

print(ss011)
print(ss111)
print(ss112)
print(ss010)
print(ss001)
print(ss101)
print(ss102)

print((ss001+ss101+ss102)/1e3)
print((ss011+ss111+ss112+ss010)/1e3)
((ss011+ss111+ss112+ss010)-(ss001+ss101+ss102))/1e3
# Out:
# 0
# 0
# 145749.316989361
# 0
# 106281.189898584
# 97179.8329130488
# 0
# 203.461022811633
# 145.749316989361
# -57.7117058222713

# %%
115.423411644543


a = 115.242071953813
x = .75
y = 1-x
a*x-y*x

-115.423411644543*.5+115.242071953813*.5
# Out:
# -0.09066984536499945

# %%
# differential from F=0 mf=0 to F=1 mf=-1

import sympy
from sympy import S
from sympy.physics.wigner import wigner_3j
from sympy.physics.wigner import wigner_6j
import numpy as np
import scipy.constants as sc

I = 2*.11/(np.pi*(29.3e-6)**2)
E = np.sqrt(2*I/(sc.c*sc.epsilon_0))

l = 563e12
a = 1/(4*np.pi*sc.epsilon_0*sc.hbar*sc.c)
gam1 = 15.1*2*np.pi*1e6
s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(1)/2
l1 = 1
f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = -1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(607.429890e12-1.815e9)
mu = np.sqrt(gam1*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss011 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w02 = 2*np.pi*(607.429890e12-qf-1.815e9)
mu2 = np.sqrt(gam1*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss001 = W2**2/(4*d2)/(2*np.pi)


s = S(1)/2
f1 = 0
mf1 = 0
j1 = S(1)/2
l1 = 1
f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = -1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(607.429890e12)
mu = np.sqrt(gam1*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss010 = W**2/(4*d)/(2*np.pi)


gam2=2*np.pi*18.8e6

s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(3)/2
l1 = 1
f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = -1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w0 = 2*np.pi*(658.118271e12+625e6)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss111 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w02 = 2*np.pi*(658.118271e12-qf+625e6)
mu2 = np.sqrt(gam2*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss101 = W2**2/(4*d2)/(2*np.pi)






A=2*np.pi*18.8e6

s = S(1)/2
f1 = 2
mf1 = 0
j1 = S(3)/2
l1 = 1
f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = -1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(658.118271e12)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss112 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2
w02 = 2*np.pi*(658.118271e12-qf)
mu2 = np.sqrt(A*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss102 = W2**2/(4*d2)/(2*np.pi)

print(ss011)
print(ss111)
print(ss112)
print(ss010)
print(ss001)
print(ss101)
print(ss102)

print((ss001+ss101+ss102)/1e3)
print((ss011+ss111+ss112+ss010)/1e3)
((ss011+ss111+ss112+ss010)-(ss001+ss101+ss102))/1e3
# Out:
# 106252.237422757
# 24291.3240116496
# 24291.5528315602
# 106246.944522572
# 106281.189898584
# 97179.8329130488
# 0
# 203.461022811633
# 261.082058788539
# 57.6210359769063

# %%
##optical

import scipy.constants as sc
import numpy as np
from sympy import *

I = 2*.05/(np.pi*(29.3e-6)**2)

E = np.sqrt(2*I/(sc.c*sc.epsilon_0))

w0 = 2*np.pi*607.429e12
A=2*np.pi*15.1e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1

f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = .5*c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(607.429-563)*1e12
ss = W**2/(4*d)/(2*np.pi)

w0 = 2*np.pi*607.429e12
A=2*np.pi*15.1e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 0
mf1 = 0
j1 = S(1)/2
l1 = 1

f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = .5*c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(607.429-563)*1e12
ss0 = W**2/(4*d)/(2*np.pi)

w0 = 2*np.pi*658.118e12
A=2*np.pi*18.8e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = .5*c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(658.118-563)*1e12
ss2 = W**2/(4*d)/(2*np.pi)



w0 = 2*np.pi*658.118e12
A=2*np.pi*18.8e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(658.118-563)*1e12
ss3 = W**2/(4*d)/(2*np.pi)









w0 = 2*np.pi*489.989e12
A=2*np.pi*5.9e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 2
mf1 = 0
j1 = S(3)/2
l1 = 1

f2 = 3
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)

mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(489.989-563)*1e12
ss4 = W**2/(4*d)/(2*np.pi)

print(I)
print(ss,ss2,ss3,ss4)
print((ss+ss2+ss3+ss0-ss4)/1e3)
# Out:
# 37077879.32110924
# 12073.8113504243 2760.41500555565 33124.9800666678 -26252.2483739779
# 74.2114547966256

# %%
##optical 0 -> 2

import scipy.constants as sc
import numpy as np
from sympy import *

I = 2*.11/(np.pi*(29.3e-6)**2)

E = np.sqrt(2*I/(sc.c*sc.epsilon_0))

w0 = 2*np.pi*(607.429e12+qf)
A=2*np.pi*15.1e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(607.429e12+qf-563e12)
ss = W**2/(4*d)/(2*np.pi)


w0 = 2*np.pi*(658.118e12+qf)
A=2*np.pi*18.8e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(658.118e12+qf-563e12)
ss2 = W**2/(4*d)/(2*np.pi)



w0 = 2*np.pi*(658.118e12+qf)
A=2*np.pi*18.8e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(658.118e12+qf-563e12)
ss3 = W**2/(4*d)/(2*np.pi)


w0 = 2*np.pi*489.989e12
A=2*np.pi*5.9e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 2
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*sympy.sqrt(2*j1+1)*x

W= E/sc.hbar*mu
d = 2*np.pi*(489.989-563)*1e12
ss4 = W**2/(4*d)/(2*np.pi)

w0 = 2*np.pi*489.989e12
A=2*np.pi*5.9e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 2
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*sympy.sqrt(2*j1+1)*x

W= E/sc.hbar*mu
d = 2*np.pi*(489.989-563)*1e12
ss5 = W**2/(4*d)/(2*np.pi)


##F7/2 shift
mu = 3.794062882e-29

s = S(1)/2
f1 = 3
mf1 = 1
j1 = S(7)/2
l1 = 1

f2 = 2
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = mu*x

W= E/sc.hbar*mu
d = 2*np.pi*(1283.358125-563)*1e12
ss6 = W**2/(4*d)/(2*np.pi)

mu = 3.794062882e-29

s = S(1)/2
f1 = 4
mf1 = 1
j1 = S(7)/2
l1 = 1

f2 = 2
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = mu*x

W= E/sc.hbar*mu
ss7 = W**2/(4*d)/(2*np.pi)

print(ss5/1e3)
print(ss4/1e3)
print(ss6/1e3)
print(ss7/1e3)
print((ss+ss2+ss3-ss5-ss6-ss4-ss7)/1e3)
# Out:
# -4.81291220189594
# -14.4387366056878
# 3.33017744760272
# 0
# 219.294147608232

# %%
# differential from F=0 mf=0 to F=1 mf=-1

import sympy
from sympy import S
from sympy.physics.wigner import wigner_3j
from sympy.physics.wigner import wigner_6j
import numpy as np
import scipy.constants as sc

I = 2*.11/(np.pi*(29.3e-6)**2)
E = np.sqrt(2*I/(sc.c*sc.epsilon_0))

l = 563e12
a = 1/(4*np.pi*sc.epsilon_0*sc.hbar*sc.c)
gam1 = 15.1*2*np.pi*1e6
s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1
f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(607.429890e12-1.815e9)
mu = np.sqrt(gam1*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss011 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(1)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w02 = 2*np.pi*(607.429890e12-qf-1.815e9)
mu2 = np.sqrt(gam1*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss001 = W2**2/(4*d2)/(2*np.pi)




gam2=2*np.pi*18.8e6

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w0 = 2*np.pi*(658.118271e12+625e6)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss111 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 0
j1 = S(3)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w02 = 2*np.pi*(658.118271e12-qf+625e6)
mu2 = np.sqrt(gam2*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss101 = W2**2/(4*d2)/(2*np.pi)






A=2*np.pi*18.8e6

s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 1
mf2 = 1
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(658.118271e12)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss112 = W**2/(4*d)/(2*np.pi)

s = S(1)/2
f1 = 2
mf1 = 0
j1 = S(3)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 0

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2
w02 = 2*np.pi*(658.118271e12-qf)
mu2 = np.sqrt(A*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss102 = W2**2/(4*d2)/(2*np.pi)

print(ss011)
print(ss111)
print(ss112)

print(ss001)
print(ss101)
print(ss102)

print((ss001+ss101+ss102)/1e3)
print((ss011+ss111+ss112)/1e3)
((ss011+ss111+ss112)-(ss001+ss101+ss102))/1e3
# Out:
# 106252.237422757
# 24291.3240116496
# 72874.6584946806
# 106281.189898584
# 97179.8329130488
# 0
# 203.461022811633
# 203.418219929087
# -0.0428028825456277

# %%
57.7117058222713/133.901619848833
# Out:
# 0.43100080407857944

# %%
9932.4515-9932.3428
# Out:
# 0.10869999999886204

# %%
5649.702006-5649.442
# Out:
# 0.2600060000004305

# %%
0.10869999999886204/0.2600060000004305
# Out:
# 0.4180672753654995

# %%
256.175828330640/219.337619439273
# Out:
# 1.1679520776487968

# %%
s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1
f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(607.429890e12-1.815e9)
mu = np.sqrt(gam1*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss011 = W**2/(4*w0)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w02 = 2*np.pi*(607.429890e12-qf-1.815e9)
mu2 = np.sqrt(gam1*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss001 = W2**2/(4*w02)/(2*np.pi)




gam2=2*np.pi*18.8e6

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2


w0 = 2*np.pi*(658.118271e12+625e6)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss111 = W**2/(4*w0)/(2*np.pi)

s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

print('hi',x)
w02 = 2*np.pi*(658.118271e12-qf+625e6)
mu2 = np.sqrt(gam2*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss101 = W2**2/(4*w02)/(2*np.pi)






A=2*np.pi*18.8e6

s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w0 = 2*np.pi*(658.118271e12)
mu = np.sqrt(gam2*3*sc.c**2/(4*a*w0**3))*x
W= E/sc.hbar*mu
d = w0-2*np.pi*l
ss112 = W**2/(4*w0)/(2*np.pi)

s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1
f2 = 0
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)*sympy.sqrt(2*f1+1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f2+1)*sympy.sqrt(2*j1+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

w02 = 2*np.pi*(658.118271e12-qf)
mu2 = np.sqrt(A*3*sc.c**2/(4*a*w02**3))*x
W2= E/sc.hbar*mu2
d2 = w02-2*np.pi*l
ss102 = W2**2/(4*w02)/(2*np.pi)



print(ss011)
print(ss111)
print(ss112)
print(ss001)
print(ss101)
print(ss102)
print(ss011-ss001)
((ss011+ss111+ss112)-(ss001+ss101+ss102))/E**2
# Out:
# hi sqrt(6)/3
# 7771.42606247832
# 3510.86093471840
# 10532.6228144325
# 7771.93402822433
# 14044.2909593826
# 0
# -0.507965746014634
# -2.13986185638525e-11

# %%
##optical

import scipy.constants as sc
import numpy as np
from sympy import *

I = 2*.11/(np.pi*(29.3e-6)**2)

E = np.sqrt(2*I/(sc.c*sc.epsilon_0))
wl = 2*np.pi*563e12
w0 = 2*np.pi*607.429e12
A=2*np.pi*15.2e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(1)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(607.429-563)*1e12
ss = W**2/(4*d)/(2*np.pi)

ssc = W**2/(4*(wl+w0))/(2*np.pi)

w0 = 2*np.pi*658.118e12
A=2*np.pi*18.9e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 1
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(658.118-563)*1e12
ss2 = W**2/(4*d)/(2*np.pi)

ssc2 = W**2/(4*(wl+w0))/(2*np.pi)


w0 = 2*np.pi*658.118e12
A=2*np.pi*18.9e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 1
mf2 = 0
j2 = S(1)/2
l2 = 0
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2*sympy.sqrt(2*j1+1)


mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*x

W= E/sc.hbar*mu
d = 2*np.pi*(658.118-563)*1e12
ss3 = W**2/(4*d)/(2*np.pi)
ssc3 = W**2/(4*(wl+w0))/(2*np.pi)


w0 = 2*np.pi*489.989e12
A=2*np.pi*5.98e6
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)


s = S(1)/2
f1 = 2
mf1 = 1
j1 = S(3)/2
l1 = 1

f2 = 3
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))*sympy.sqrt(2*j1+1)*x

W= E/sc.hbar*mu
d = 2*np.pi*(489.989-563)*1e12
ss4 = W**2/(4*d)/(2*np.pi)
ssc4 = W**2/(4*(wl+w0))/(2*np.pi)

##F7/2 shift
mu = 3.794062882e-29

s = S(1)/2
f1 = 3
mf1 = 1
j1 = S(7)/2
l1 = 1

f2 = 3
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = mu*x

W= E/sc.hbar*mu
d = 2*np.pi*(1283.358125-563)*1e12
ss5 = W**2/(4*d)/(2*np.pi)

mu = 3.794062882e-29

s = S(1)/2
f1 = 4
mf1 = 1
j1 = S(7)/2
l1 = 1

f2 = 3
mf2 = 0
j2 = S(5)/2
l2 = 2
q = 1

c1 = wigner_3j(f1, 1, f2, -mf1, q , mf2)*(-1)**(f1-mf1)
c2 = wigner_6j(j1,f1,S(1)/2,f2,j2,1)*sympy.sqrt(2*f1+1)*sympy.sqrt(2*f2+1)*(-1)**(j1+S(1)/2+f2+1)
x = c1*c2

mu = mu*x

W= E/sc.hbar*mu
ss6 = W**2/(4*d)/(2*np.pi)

print(ss6/1e3)
print(ssc/1e3,ssc2/1e3,ssc3/1e3,ssc4/1e3)
print((ss+ss2+ss3+(ssc+ssc2+ssc3)-ss5-ss6-ss4-ssc4)/1e3)
print((ss+ss2+ss3-ss4)/1e3)
# Out:
# 3.12204135712755
# 4.05989837879701 1.90224338959370 5.70673016878110 1.35294943427809
# 231.135064245626
# 224.149319190335

# %%
import numpy as np
import scipy.constants as sc
I = 2*.04/(np.pi*(10e-6)**2)
a = 1/(4*np.pi*sc.epsilon_0*sc.hbar*sc.c)

E = np.sqrt(2*I/(sc.c*sc.epsilon_0))

w0 = 2*np.pi*824.28e12
t = 3.18e-8
A= .24*1/t
print(A/(2*np.pi))
k = (3*np.pi*sc.epsilon_0*sc.hbar*sc.c**3)/(w0**3)




mu = np.sqrt(A*3*sc.c**2/(4*a*w0**3))
print(mu)
W= E/sc.hbar*mu

d = 2*np.pi*(824-844)*1e12
d2 = 2*np.pi*(824-844.00362)*1e12

ss = W**2/(4*d)/(2*np.pi)
ss2 = W**2/(4*d2)/(2*np.pi)
print(ss)
print(ss-ss2)
print(d/(2*np.pi*1e12))
print(W)
# Out:
# 1201169.3818256252
# 3.589129911553971e-30
# -70368.28843508809
# -12.734355288281222
# -20.0
# 14907793067.907223
