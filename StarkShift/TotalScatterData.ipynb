# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.optimize import curve_fit
import numpy as np

# %%
def func(x, *params):
    y = np.zeros_like(x)
    k = params[0]
    y0 = params[1]
    y = y + k*x + y0
    return y

# guess = [1,0]
# npopt, npcov = curve_fit(func, x, y, p0=guess, sigma = nysig)
# nx_fit = np.linspace(0,200,100000)
# nfit = func(nx_fit, *npopt)
# print(npopt)
# print(np.sqrt(np.diag(npcov)))

# %%
xme = np.linspace(0,1000,10000)
slope = 0.11637691021052336/41.95672707316164
slope3 = 0.00186151   + 0.00025585  
slope4 = 0.00186151   - 0.00025585 
slope5 = 0.16195790568863447/42.8028825456277

yme = slope*xme
yerrp = slope3*xme
yerrm = slope4*xme
oy = slope5*xme

# %%
##Plotting Results###
plt.rcParams['figure.figsize'] = [20, 12]
plt.rcParams.update({'font.size': 22})

fig = plt.figure()
#fig.suptitle('Total 532 Scattering Rate', fontsize=20)
ax = fig.gca()
ax.ticklabel_format(useOffset=False)
ax.patch.set_facecolor('lightgrey')
ax.patch.set_alpha(.5)
plt.xlabel("Stark Shift (Hz)",fontsize=30)
plt.ylabel("Scattering Rate ($s^{-1}$)",fontsize=30)

# plt.errorbar(xdata,ydata, xerr =xsig, yerr=ysig, fmt='o',color ='black',label = 'Measured $\pi$ light', capsize=2)
plt.plot(xme, oy, color = 'green', label = 'Previous Theory [1]', linewidth = 4)

plt.plot(xme,yme, color = 'r', label = 'New Theory [2]', linewidth = 4)



# plt.errorbar(newx,newy, yerr=ysig, fmt='o',color ='black',label = 'Experimental Data', capsize=2)
# plt.plot(xme,xme*model.coef_, color = 'blue', label = 'Experimental Fit',linewidth = 4)
# plt.plot(xme,yerrp,'b--',label = '1 $\sigma$ Fit' )
# plt.plot(xme,yerrm,'b--')

plt.legend(loc="upper left",fontsize=30)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.grid(linewidth=2)
plt.tight_layout()
# plt.savefig("Z:\Group_Share\Barium\Posters and Presentations\DAMOP 2022\Total_Scat_pdf2.pdf", dpi = 2000, transparent=True)
plt.show()

# %%
print(slope)
# Out:
# 0.002773736616957568

# %%
0.10377168669129545/47.866962819302
# Out:
# 0.002167918760232063

# %%
0.10377168669129545/0.11637691021052336
# Out:
# 0.8916862159647878

# %%
1.259/1.469
# Out:
# 0.8570456092579986

# %%
0.10377168669129545/256.175828330640
# Out:
# 0.0004050799303256661

# %%
0.11631084607745319/224.149319190335
# Out:
# 0.0005188989486900406

# %%
0.16195790568863447/261.171094502044
# Out:
# 0.0006201218630163796

# %%
 0.16195790568863447/224.149319190335
# Out:
# 0.0007225447138258266

# %%
0.02175818722054094/224.149319190335
# Out:
# 9.707005713483837e-05

# %%
0.9077427113548436/1803.88310276570
# Out:
# 0.0005032159289940126
