# %%
import sympy
from sympy import S
from sympy.physics.wigner import wigner_3j
from sympy.physics.wigner import wigner_6j
import numpy as np
import scipy.constants as sc

I = 2*.11/(np.pi*(29.3e-6)**2)
E = np.sqrt(2*I/(sc.c*sc.epsilon_0))
w = 2*np.pi*563e12
a = 1/(4*np.pi*sc.epsilon_0*sc.hbar*sc.c)

gam1ps = 2*np.pi*15.1e6
gam2ps = 2*np.pi*18.8e6
gam1pd1 = 2*np.pi*5.3e6
gam2pd1 = 2*np.pi*.7e6
gam2pd2 = 2*np.pi*5.9e6


###i = |F=0, mf=0, L=0> ###
si = S(1)/2
fi = 0
mfi = 0
ji = S(1)/2
li = 0
wi = 2*np.pi*(9.925e9)
q= 0

# %%
##--------------------- f = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sf = S(1)/2
ff = 1
mff = -1
jf = S(1)/2
lf = 0

wf = 2*np.pi*(0)
con = (E**2*(w-wf)**3)/(12*np.pi*sc.c**3*sc.epsilon_0*sc.hbar**3)


##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


##l --> f e_q ##
glf = gam1ps
gli = gam1ps

c1 = wigner_3j(fl.00, 1, ff, -mfl,  q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,f.........................................l,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu111 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x


#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu112 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu121 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu122 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t11 = mu121*mu122/(wl-w)
t12 = mu111*mu112/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)

glf = gam1ps
gli = gam1ps

c1 = wigner_3j(fl, 1, ff, -mfl,  q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu211 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x


#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu212 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu221 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu222 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t21 = mu221*mu222/(wl-w)
t22 = mu211*mu212/(wl+w-wf)


##--------------------- l = |F=1, J=1/2, L=0, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(1)/2
ll = 1
wl = 2*np.pi*(607.429890e12-1.815e9)


glf = gam1ps
gli = gam1ps

##l --> f e_q ##
c1 = wigner_3j(fl, 1, ff, -mfl,  q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu311 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x


#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu312 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu321 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu322 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t31 = mu321*mu322/(wl-w)
t32 = mu311*mu312/(wl+w-wf)

##--------------------- l = |F=1, J=1/2, L=0, mf=-1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = -1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)

glf = gam2ps
gli = gam2ps

##l --> f e_q ##
c1 = wigner_3j(fl, 1, ff, -mfl,  q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu411 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x


#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu412 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu421 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu422 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t41 = mu421*mu422/(wl-w)
t42 = mu411*mu412/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=0> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 0
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2ps
gli = gam2ps

##l --> f e_q ##
c1 = wigner_3j(fl, 1, ff, -mfl,  q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu511 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x


#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu512 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu521 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu522 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t51 = mu521*mu522/(wl-w)
t52 = mu511*mu512/(wl+w-wf)

##--------------------- l = |F=1, J=3/2, L=1, mf=1> -----------------------------##
sl = S(1)/2
fl = 1
mfl = 1
jl = S(3)/2
ll = 1
wl = 2*np.pi*(658.115271e12+625e6)


glf = gam2ps
gli = gam2ps

##l --> f e_q ##
c1 = wigner_3j(fl, 1, ff, -mfl,  q , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu611 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x


#i -- > l e_sc ##
c1 = wigner_3j(fl, 1, fi, -mfl, mfl-mfi , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu612 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

##l --> f e_sc ##

c1 = wigner_3j(fl, 1, ff, -mfl,  mfl-mff , mff)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,ff,jf,1)*sympy.sqrt(2*ff+1)*(-1)**(jf+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu621 = np.sqrt(glf*3*sc.c**2/(4*a*wl**3))*x

#i -- > l e_q ##
c1 = wigner_3j(fl, 1, fi, -mfl, q , mfi)*(-1)**(fl-mfl)*sympy.sqrt(2*fl+1)
c2 = wigner_6j(jl,fl,S(1)/2,fi,ji,1)*sympy.sqrt(2*fi+1)*(-1)**(ji+S(1)/2+fl+1)
x = c1*c2*sympy.sqrt(2*jl+1)

mu622 = np.sqrt(gli*3*sc.c**2/(4*a*wl**3))*x

t61 = mu621*mu622/(wl-w)
t62 = mu611*mu612/(wl+w-wf)

term1 = (t22+t52)**2
